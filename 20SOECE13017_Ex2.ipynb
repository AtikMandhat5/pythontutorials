# %% [markdown]
# # **Name: Atik Mandhat**
# # **Enrollment No.:20SOECE13017**
# # **Class:5CEB**

# %% [markdown]
# # **Experiment-2 Writing a class and creating an instance**

# %% [markdown]
# ![Experiment-2 Writing a class and creating an instance.PNG](data:image/png;base64,...)

# %%
class Employee:
    
    name= input("Enter Name:")
    age=25
    salary=25000
       
    
Emp_1=Employee()
    
print("emp_1.name", Emp_1.name )
print("emp_1.salary", Emp_1.salary)
# Out:
# Enter Name:Atik
# emp_1.name Atik
# emp_1.salary 25000
