# %% [markdown]
# # **Name: Atik Mandhat**
# # **Enrollment No.:20SOECE13017**
# # **Class:5CEB**

# %% [markdown]
# # **Experiment-10**

# %% [markdown]
# ![1.PNG](data:image/png;base64,...)

# %%
import re
word = input("Enter Word: ")

pattern = r"co"

if re.match(pattern,word):
  print('Match');
else:
  print('No Match');
# Out:
# Enter Word: col
# Match
