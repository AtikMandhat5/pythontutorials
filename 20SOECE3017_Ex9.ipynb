# %% [markdown]
# # **Name: Atik Mandhat*
# # **Enrollment No.:20SOECE13017**
# # **Class:5CEB**

# %% [markdown]
# # **Experiment-9 Using base and derived class**

# %% [markdown]
# ![Experiment-9 Using base and derived class.PNG](data:image/png;base64,...)

# %%
class Person:
    def setName(self,name):
        self.name=name
        
    def getName(self): 
        return self.name
    
    
class Student(Person): 
    
     def setAge(self,name):
        self.age=age   
    
     def getAge(self):
        return self.age

    
name=input("Enter Name:")    
age=input("Enter Age:")

s1=Student()
s1.setName(name)
s1.setAge(age)

print(s1.getName())
print(s1.getAge())
# Out:
# Enter Name:Atik
# Enter Age:21
# Atik
# 21
