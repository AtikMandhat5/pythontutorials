# %% [markdown]
# # **Name: Atik Mandhat**
# # **Enrollment No.:20SOECE13017**
# # **Class:5CEB**

# %% [markdown]
# # **Experiment-13**

# %% [markdown]
# ![4.PNG](data:image/png;base64,...)

# %%
import re
word = input("Enter Word: ")
pattern = r"^h...o$"

if re.match(pattern,word):
  print("Match");
else:
  print("No Match");
# Out:
# Enter Word: hello
# Match
