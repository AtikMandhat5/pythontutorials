# %% [markdown]
# # **Name: Atik Mandhat**
# # **Enrollment No.:20SOECE13017**
# # **Class:5CEB**

# %% [markdown]
# # **Experiment-15**

# %% [markdown]
# ![15.PNG](data:image/png;base64,...)

# %%
import re
password = input("Enter Password: ")

pattern = r".*[@#_&$A-Z].*[a-z].*[0-9]"
if (re.search(pattern,password)):
  if (len(password)<=8):
    print("Password Successfully Created");
  else:
    print("Password length is must be 8 charecter");
else:
  print("Wrong Password Fromate");
# Out:
# Enter Password: Atik@123
# Password Successfully Created
