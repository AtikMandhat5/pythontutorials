# %% [markdown]
# # **Name: Atik Mandhat**
# # **Enrollment No.:20SOECE13017**
# # **Class:5CEB**

# %% [markdown]
# # **Experiment-4 Writing a class using a self variable as method parameter**

# %% [markdown]
# ![Experiment-4 Writing a class using a self variable as method parameter.PNG](data:image/png;base64,...)

# %%
# write your code here

class Car:    
    def setName(self,name):
        self.name=name
     
    def getName(self):
        return self.name

Honda = Car()    
name=input("Enter Car Name::")

Honda.setName(name)

print(f"Honda Car Name:  { Honda.getName() }")
# Out:
# Enter Car Name::Audi Q3
# Honda Car Name:  Audi Q3
