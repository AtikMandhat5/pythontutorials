# %% [markdown]
# # **Name: Atik Mandhat**
# # **Enrollment No.:20SOECE13017**
# # **Class:5CEB**

# %% [markdown]
# # **Experiment-11**

# %% [markdown]
# ![2.PNG](data:image/png;base64,...)

# %%
import re
quote = "A great chef is first a great technician."
word = input("Enter Word: ")
a = re.findall(word,quote)
print(a);
# Out:
# Enter Word: great
# ['great', 'great']

# %%
class Cat:
    __init__(self,color,leg):
        self.color=color;
        self.
