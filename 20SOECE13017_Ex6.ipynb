# %% [markdown]
# # **Name: Atik Mandhat**
# # **Enrollment No.:20SOECE3017**
# # **Class:5CEB**

# %% [markdown]
# # **Experiment-6 Writing a class using __init__ method**

# %% [markdown]
# ![Experiment-6 Writing a class using __init__ method.PNG](data:image/png;base64,...)

# %%
class Student:
    def __init__(self,name,age,email):
        self.name=name
        self.age=age
        self.email=email

s1_name=input("Enter Name Student1:")
s1_age=int(input("Enter Age Student1:"))

stud1=Student(s1_name, s1_age, "arya@mgail.com")

        
s2_name=input("Enter Name Student2:")
s2_age=int(input("Enter Age Student2:"))
stud2=Student(s2_name,s2_age,"geeta@mgail.com")

   
print("stude_1.name",stud1.name)
print("stude_2.name",stud2.name)
# Out:
# Enter Name Student1:Atik
# Enter Age Student1:21
# Enter Name Student2:Arya
# Enter Age Student2:21
# stude_1.name Atik
# stude_2.name Arya
