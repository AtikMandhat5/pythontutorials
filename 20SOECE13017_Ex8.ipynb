# %% [markdown]
# # **Name: Atik Mandhat**
# # **Enrollment No.:20SOECE3017**
# # **Class:5CEB**

# %% [markdown]
# # **Experiment-8 Writing a program with methods**

# %% [markdown]
# ![Experiment-8 Writing a program with methods.PNG](data:image/png;base64,...)

# %%
class Person:
    def setName(self,name):
        self.name=name
        
    def getName(self):
        return self.name
        
p1=Person()
name1=input("Enter name1:")
p1.setName(name1)


p2=Person()
name2=input("Enter name2:")
p2.setName(name2)

print("Person 1 Name::", p1.getName())
print("Person 2 Name:: ",p2.getName())
# Out:
# Enter name1:Atik
# Enter name2:Anuska
# Person 1 Name:: Atik
# Person 2 Name::  Anuska
