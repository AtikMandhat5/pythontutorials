# %% [markdown]
# # **Name: Atik Mandhat**
# # **Enrollment No.:20SOECE13017**
# # **Class:5CEB**

# %% [markdown]
# # **Experiment-12**

# %% [markdown]
# ![3.PNG](data:image/png;base64,...)

# %%
import re
number = input("Enter Number: ")
pattern =r"00"
new = re.sub(pattern,"91",number)
print(int(new));
# Out:
# Enter Number: 009456471
# 919456471
