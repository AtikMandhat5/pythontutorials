# %% [markdown]
# # **Name: Atik Mandhat**
# # **Enrollment No.:20SOECE13017**
# # **Class:5CEB**

# %% [markdown]
# # **Experiment-16**

# %% [markdown]
# ![16.PNG](data:image/png;base64,...)

# %%
import re
text = input("Enter Text: ")
a= re.findall(r"#\w+",text)
print("\n".join(a));
# Out:
# Enter Text: #Covid19 is also known as #corona #virus ...
# #Covid19
# #corona
# #virus
