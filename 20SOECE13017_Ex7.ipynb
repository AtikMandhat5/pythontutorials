# %% [markdown]
# # **Name: Atik Mandhat**
# # **Enrollment No.:20SOECE3017**
# # **Class:5CEB**

# %% [markdown]
# # **Experiment-7 Write a program to take name and salary as input from the user and print the details of the employee as shown in the sample test cases**

# %% [markdown]
# ![Experiment-7 Write a program to take name and salary as input from the user and print the details of the employee as shown in th.PNG](data:image/png;base64,...)

# %%
class Employee:
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary
        
    def displayEmployee(self):
        print(f"Name {self.name} - Salary:{self.salary}")
        
name=input("Enter Name:")
salary=input("Enter Salary:")

emp=Employee(name,salary)
emp.displayEmployee()
# Out:
# Enter Name:Atikk
# Enter Salary:25000
# Name Atikk - Salary:25000
